# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# import os
# os.environ["CUDA_LAUNCH_BLOCKING"] = "1" 
# # Install system deps
# !apt-get update -y
# !apt-get install -y ffmpeg
# # Install lerobot (dataset is v3)
# # !pip install -U lerobot
# !pip install lerobot==0.1.0
# !pip install "lerobot[smolvla]"

# %%
# install micromamba 
# !wget -qO micromamba.tar.bz2 https://micro.mamba.pm/api/micromamba/linux-64/latest
# !tar -xjf micromamba.tar.bz2
# create env with Python 3.10
# !./bin/micromamba create -y -n lerobot_env python=3.10
# install ffmpeg
# !./bin/micromamba install -y -n lerobot_env -c conda-forge ffmpeg
# upgrade pip (prevents silent failures)
# !./bin/micromamba run -n lerobot_env pip install --upgrade pip
# install lerobot
# !./bin/micromamba run -n lerobot_env pip install git+https://github.com/huggingface/lerobot.git
# install extras
# !./bin/micromamba run -n lerobot_env pip install "lerobot[smolvla]"
# Out:
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# conda-forge/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# [+] 0.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━━   1.8MB /  52.2MB @  11.5MB/s  0.1s
# conda-forge/noarch   ━╸━━━━━━━━━━━━━━━━━━━━━   2.6MB /  25.4MB @  16.7MB/s  0.1s
# [+] 0.3s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━━━━━━   7.7MB /  52.2MB @  29.6MB/s  0.2s
# conda-forge/noarch   ━━━━━━╸━━━━━━━━━━━━━━━━   8.3MB /  25.4MB @  32.3MB/s  0.2s
# [+] 0.4s
# conda-forge/linux-64 ━━━━╸━━━━━━━━━━━━━━━━━━  13.0MB /  52.2MB @  35.8MB/s  0.3s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━  13.6MB /  25.4MB @  37.8MB/s  0.3s
# [+] 0.5s
# conda-forge/linux-64 ━━━━━━╸━━━━━━━━━━━━━━━━  18.1MB /  52.2MB @  38.9MB/s  0.4s
# conda-forge/noarch   ━━━━━━━━━━━━━━━╸━━━━━━━  18.8MB /  25.4MB @  40.4MB/s  0.4s
# [+] 0.6s
# conda-forge/linux-64 ━━━━━━━━━╸━━━━━━━━━━━━━  23.1MB /  52.2MB @  40.8MB/s  0.5s
# ...

# %%
# %%writefile test_env.py
import torch, lerobot
print("CUDA:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
print("Torch:", torch.__version__)
print("LeRobot:", lerobot.__file__)
# Out:
# Writing test_env.py

# %%
# !./bin/micromamba run -n lerobot_env python test_env.py
# Out:
# CUDA: True
# GPU: Tesla T4
# Torch: 2.10.0+cu128
# LeRobot: /root/.local/share/mamba/envs/lerobot_env/lib/python3.10/site-packages/lerobot/__init__.py

# %%
# %%writefile test_env.py
from huggingface_hub import login
login("hf_frV..")   # your token
print("Logged In - Done")
# Out:
# Overwriting test_env.py

# %%
# !./bin/micromamba run -n lerobot_env python test_env.py
# Out:
# Logged In - Done

# %%
# !./bin/micromamba run -n lerobot_env lerobot-train \
  --dataset.repo_id Sri-Ram-A/pnp1 \
  --dataset.revision v3.0 \
  --policy.repo_id Sri-Ram-A/smolvla_pnp1 \
  --policy.type smolvla \
  --policy.pretrained_path HuggingFaceVLA/smolvla_libero \
  --policy.expert_width_multiplier 0.5 \
  --policy.num_vlm_layers 0 \
  --policy.vlm_model_name HuggingFaceTB/SmolVLM2-500M-Instruct \
  --output_dir outputs/smolvla \
  --job_name smolvla_pnp1 \
  --batch_size 16 \
  --steps 20000 \
  --optimizer.lr 1e-5 \
  --num_workers 4 \
  --save_freq 1000 \
  --eval_freq 900 \
  --wandb.enable false \
  --policy.push_to_hub true \
  --save_checkpoint true
# Out:
# WARNING:lerobot.configs.policies:Device 'None' is not available. Switching to 'cuda'.
# INFO 2026-03-30 06:08:08 ot_train.py:197 {'batch_size': 16,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
# ...
