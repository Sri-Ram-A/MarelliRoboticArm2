# %%
! lerobot-info
# Out:
# Copy-and-paste the text below in your GitHub issue and FILL OUT the last point.
#
# - lerobot version: 0.4.2
# - Platform: Windows-11-10.0.26200-SP0
# - Python version: 3.13.5
# - Huggingface Hub version: 0.35.3
# - Datasets version: 4.1.1
# - Numpy version: 2.3.4
# - PyTorch version: 2.7.0+cu126
# - Is PyTorch built with CUDA support?: True
# - Cuda version: 12.6
# - GPU model: NVIDIA GeForce RTX 2050
# - Using GPU in script?: <fill in>

# %%
! python -m lerobot.datasets.v30.convert_dataset_v21_to_v30 --repo-id=Sri-Ram-A/dataset-silver-metal-1
# Out:
# Trying to download v3.0 version of the dataset from the hub...
# Dataset does not have an uploaded v3.0 version. Continuing with conversion.
# tag=v3.0 probably doesn't exist. Skipping exception (404 Client Error. (Request ID: Root=1-694fad09-6752f1264d34c9df3d81481e;e689286b-5332-4e61-af8c-541a1a660e46)
#
# Revision Not Found for url: https://huggingface.co/api/datasets/Sri-Ram-A/dataset-silver-metal-1/tag/v3.0.
# Invalid rev id: v3.0)
# Fetching 45 files:   0%|          | 0/45 [00:00<?, ?it/s]Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
! lerobot-train \
  --policy="{type: act}" \
  --dataset.repo_id=Sri-Ram-A/dataset-silver-metal-1 \
  --steps=200 \
  --batch_size=8 \
  --policy.push_to_hub=true \
  --policy.repo_id=Sri-Ram-A/policy-act-silver-metal-1
# Out:
# ^C

# %%
# ! lerobot-train --config_path train.yaml
