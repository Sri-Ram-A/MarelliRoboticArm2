# %% [markdown]
# created conda Environment
# conda install -c conda-forge make -y # install make
# make --version
#
# pip install uv # install uv package
# uv --version
#
# # https://modal.com/apps/srirama-ai23/main
# pip install modal
# modal setup
# modal --version
# modal environment list # output : main

# %% [markdown]
# git clone https://github.com/phospho-app/phosphobot.git
# cd phosphobot/modal
# make install
# - Error : error: Microsoft Visual C++ 14.0 or greater is
#       required. Get it with "Microsoft C++ Build Tools":
#       https://visualstudio.microsoft.com/visual-cpp-build-tools/
#
#       hint: This usually indicates a problem with the package
#       or the build environment.
#   help: `pybullet` (v3.2.7) was included because `inference`
#         (v0.1.0) depends on `phosphobot` (v0.3.134) which
#         depends on `pybullet`
# Solution : Download [Microsoft Visual C++](https://visualstudio.microsoft.com/visual-cpp-build-tools/)

# %%
# SriRam.A@369@phosphobot password 
#  modal api key below
[srirama-ai23]
token_id = "ak-sY58M5sOBK5yalxGLjBEqt"
token_secret = "as-yWZ020F5nFMFphky0SBMO6"
active = true

# %%
! curl --request POST --url http://localhost/calibrate
