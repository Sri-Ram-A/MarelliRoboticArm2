# %% [markdown]
# https://docs.phospho.ai/learn/ai-models#train-an-act-model-locally-with-lerobot

# %% [markdown]
# ```bash
# uv run lerobot/lerobot/scripts/train.py `
#   --dataset.repo_id=Sri-Ram-A/example_dataset `
#   --policy.type=act `
#   --output_dir=outputs/train/phoshobot_test `
#   --job_name=phosphobot_test `
#   --policy.device=cuda
# ```
# Training done in colab -
